# %%
  from personal_ai import rayansh_ai
  import asyncio

  async def test():
      # Initialize
      await rayansh_ai.initialize()

      # Chat
      response = await rayansh_ai.chat(
          "hey do u like sports?",
          session_id="user123"
      )

      print(response["message"])
      print(f"Model: {response['model']}")

  asyncio.run(test())
# Out:
# c:\Users\Amit\AppData\Local\Programs\Python\Python310\lib\site-packages\google\cloud\aiplatform\models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [1], line 17
#      14     print(response["message"])
#      15     print(f"Model: {response['model']}")
# ---> 17 asyncio.run(test())
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python310\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ...

# %%
import os
import requests
def send_simple_message():
  	return requests.post(
  		"https://api.mailgun.net/v3/sandboxac6f361516924e1fa1909bf3adf80c1c.mailgun.org/messages",
  		auth=("api", os.getenv('API_KEY', 'API_KEY')),
  		data={"from": "Mailgun Sandbox <postmaster@sandboxac6f361516924e1fa1909bf3adf80c1c.mailgun.org>",
			"to": "Rayansh Srivastava <rayanshsrivastava1@gmail.com>",
  			"subject": "Hello Rayansh Srivastava",
  			"text": "Congratulations Rayansh Srivastava, you just sent an email with Mailgun! You are truly awesome!"})
send_simple_message()
# Out:
# <Response [200]>
